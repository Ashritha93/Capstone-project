# %% [markdown]
# #                          Zomato Recommendation System

# %% [markdown]
# # Context
#  I was always fascinated by the food culture of Bengaluru. Restaurants from all over the world can be found
#  here in Bengaluru. From United States to Japan, Russia to Antarctica, you get all type of cuisines here.
#  Delivery, Dine-out, Pubs, Bars, Drinks,Buffet, Desserts you name it and Bengaluru has it.
#  Currently which stands at approximately 12,000 restaurants.
# With such an high number of restaurants. This industry hasn't been saturated yet.
# And new restaurants are opening every day. However it has become difficult for them to compete with already established restaurants.
#
# The key issues that continue to pose a challenge to them include high real estate costs, rising food costs, shortage of quality manpower, fragmented supply chain and over-licensing. This Zomato data aims at analysing demography of the location. Most importantly it will help new restaurants
# in deciding their theme, menus, cuisine, cost etc for a particular location. It also aims at finding similarity between neighborhoods of Bengaluru on the basis of food. The dataset also contains reviews for each of the restaurant which
# will help in finding overall rating for the place.
#
# In this notebook I will try analyzing the Buisness Problem of Zomato and create a practical recommendation system for users.

# %% [markdown]
# # What is Recommendation System?
#
# The rapid growth of data collection has led to a new era of information. Data is being used to create more efficient systems and this is where Recommendation Systems come into play. Recommendation Systems are a type of information filtering systems as they improve the quality of search results and provides items that are more relevant to the search item or are realted to the search history of the user. They are active information filtering systems which personalize the information coming to a user based on his interests, relevance of the information etc. Recommender systems are used widely for recommending movies, articles, restaurants, places to visit, items to buy etc.
#
# There are basically three types of recommender systems:-
#
# Demographic Filtering- They offer generalized recommendations to every user, based on movie popularity and/or genre. The System recommends the same movies to users with similar demographic features.
#
# Content Based Filtering- They suggest similar items based on a particular item. This system uses item metadata, such as genre, director, description, actors, etc. for movies, to make these recommendations.
#
# Collaborative Filtering- This system matches persons with similar interests and provides recommendations based on this matching. Collaborative filters do not require item metadata like its content-based counterparts.
#
# Here I will be using Content Based Filtering
#
# Content-Based Filtering: This method uses only information about the description and attributes of the items users has previously consumed to model user's preferences. In other words, these algorithms try to recommend items that are similar to those that a user liked in the past (or is examining in the present). In particular, various candidate items are compared with items previously rated by the user and the best-matching items are recommended.
#
# This data set consists of restaurants of Bangalore,India collected from Zomato.
#
# My aim is to create a content based recommender system in which when I will write a restaurant name, Recommender system will look at the reviews of other restaurants, and System will recommend us other restaurants with similar reviews and sort them from the highest rated.

# %% [markdown]
# # Breakdown of this notebook:¶
#
# 1.#Loading the dataset: Load the data and import the libraries.
# 2.# Data Cleaning:
#        . Deleting redundant columns.
#        . Renaming the columns.
#        . Dropping duplicates.
#        . Cleaning individual columns.
#        . Remove the NaN values from the dataset
#         #Some Transformations
# 3.#Text Preprocessing
#     .Cleaning unnecessary words in the reviews
#     . Removing links and other unncessary items
#     . Removing Symbols
# 4.#Recommendation System

# %% [markdown]
# # Importing Libraries

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Loading the dataset

# %%
#reading the dataset
zomato_real=pd.read_csv("C:/Users/ASHRITHA/Downloads/Zomato_reduced.csv")
zomato_real.head() # prints the first N rows of a DataFrame
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes                             phone  \
# 0          Yes        Yes   4.1  775.0    080 42297555\r\n+91 9743772233
# 1          Yes         No   4.1  787.0                      080 41714161
# 2          Yes         No   3.8  918.0                    +91 9663487993
# 3           No         No   3.7   88.0                    +91 9620009302
# 4           No         No   3.8  166.0  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  ...                        cuisines  \
# 0  Banashankari        Casual Dining  ...  North Indian, Mughlai, Chinese
# 1  Banashankari        Casual Dining  ...     Chinese, North Indian, Thai
# 2  Banashankari  Cafe, Casual Dining  ...          Cafe, Mexican, Italian
# 3  Banashankari          Quick Bites  ...      South Indian, North Indian
# 4  Basavanagudi        Casual Dining  ...        North Indian, Rajasthani
#
#   approx_cost(for two people)  \
# 0                       800.0
# 1                       800.0
# 2                       800.0
# 3                       300.0
# 4                       600.0
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)  \
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari
#
#                               liked_food_from_review  \
# 0  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...         12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...         12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...         12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...         12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...         12.941726
#
#    location_longitude
# 0           77.573638
# 1           77.573638
# 2           77.573638
# 3           77.573638
# 4           77.575502
#
# [5 rows x 21 columns]

# %%
zomato_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9253 entries, 0 to 9252
# Data columns (total 21 columns):
# url                            9253 non-null object
# address                        9253 non-null object
# name                           9253 non-null object
# online_order                   9253 non-null object
# book_table                     9253 non-null object
# rate                           9253 non-null float64
# votes                          9253 non-null float64
# phone                          9116 non-null object
# location                       9253 non-null object
# rest_type                      9216 non-null object
# dish_liked                     4545 non-null object
# cuisines                       9250 non-null object
# approx_cost(for two people)    9253 non-null float64
# reviews_list                   9253 non-null object
# menu_item                      9253 non-null object
# listed_in(type)                9253 non-null object
# listed_in(city)                9253 non-null object
# liked_food_from_review         9253 non-null object
# menus_combined                 4545 non-null object
# location_latitude              9253 non-null float64
# location_longitude             9253 non-null float64
# dtypes: float64(5), object(16)
# memory usage: 1.5+ MB

# %% [markdown]
# # Data Cleaning and Feature Engineering¶

# %%
#Deleting Unnnecessary Columns
zomato=zomato_real.drop(['url','dish_liked','phone'],axis=1) #Dropping the column "dish_liked", "phone", "url" and saving the new dataset as "zomato"

# %%
#Removing the Duplicates
zomato.duplicated().sum()
zomato.drop_duplicates(inplace=True)

# %%
#Remove the NaN values from the dataset
zomato.isnull().sum()
zomato.dropna(how='any',inplace=True)
zomato.info() #.info() function is used to get a concise summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4529 entries, 0 to 9252
# Data columns (total 18 columns):
# address                        4529 non-null object
# name                           4529 non-null object
# online_order                   4529 non-null object
# book_table                     4529 non-null object
# rate                           4529 non-null float64
# votes                          4529 non-null float64
# location                       4529 non-null object
# rest_type                      4529 non-null object
# cuisines                       4529 non-null object
# approx_cost(for two people)    4529 non-null float64
# reviews_list                   4529 non-null object
# menu_item                      4529 non-null object
# listed_in(type)                4529 non-null object
# listed_in(city)                4529 non-null object
# liked_food_from_review         4529 non-null object
# menus_combined                 4529 non-null object
# location_latitude              4529 non-null float64
# location_longitude             4529 non-null float64
# dtypes: float64(5), object(13)
# memory usage: 672.3+ KB

# %%
#Reading Column Names
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)',
#        'liked_food_from_review', 'menus_combined', 'location_latitude',
#        'location_longitude'],
#       dtype='object')

# %%
#Changing the column names
zomato = zomato.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                                  'listed_in(city)':'city'})
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city', 'liked_food_from_review', 'menus_combined',
#        'location_latitude', 'location_longitude'],
#       dtype='object')

# %%
#Some Transformations
zomato['cost'] = zomato['cost'].astype(str) #Changing the cost to string
zomato['cost'] = zomato['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost
zomato['cost'] = zomato['cost'].astype(float) # Changing the cost to Float
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4529 entries, 0 to 9252
# Data columns (total 18 columns):
# address                   4529 non-null object
# name                      4529 non-null object
# online_order              4529 non-null object
# book_table                4529 non-null object
# rate                      4529 non-null float64
# votes                     4529 non-null float64
# location                  4529 non-null object
# rest_type                 4529 non-null object
# cuisines                  4529 non-null object
# cost                      4529 non-null float64
# reviews_list              4529 non-null object
# menu_item                 4529 non-null object
# type                      4529 non-null object
# city                      4529 non-null object
# liked_food_from_review    4529 non-null object
# menus_combined            4529 non-null object
# location_latitude         4529 non-null float64
# location_longitude        4529 non-null float64
# dtypes: float64(5), object(13)
# memory usage: 672.3+ KB

# %%
#Reading Rate of dataset
zomato['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 4.6, 4. , 4.2, 3.9, 3. , 3.6, 2.8, 4.4, 3.1, 4.3,
#        2.6, 3.3, 3.5, 3.2, 4.5, 2.5, 2.9, 3.4, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
# Adjust the column names
zomato.name = zomato.name.apply(lambda x:x.title())
zomato.online_order.replace(('Yes','No'),(True, False),inplace=True)
zomato.book_table.replace(('Yes','No'),(True, False),inplace=True)
zomato.cost.unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         750.,  200.,  850., 1200.,  150.,  350.,  250., 1500., 1300.,
#        1000.,  100.,  900., 1100., 1600.,  950.,  230., 1700., 1350.,
#        2200., 1400., 2000., 1800., 1900.,  180.,  330., 2500., 2100.,
#        3000., 2800., 3400.,   40., 1250., 3500., 4000., 2400., 1450.,
#        3200., 6000., 1050., 4100., 2300.,  120., 2600., 5000., 3700.,
#        1650., 2700., 4500.])

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1  775.0  Banashankari        Casual Dining
# 1          True       False   4.1  787.0  Banashankari        Casual Dining
# 2          True       False   3.8  918.0  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7   88.0  Banashankari          Quick Bites
# 4         False       False   3.8  166.0  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city                             liked_food_from_review  \
# 0  Banashankari  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  Banashankari  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  Banashankari  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  Banashankari  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  Banashankari  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined  location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...          12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...          12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...          12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...          12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...          12.941726
#
#    location_longitude
# 0           77.573638
# 1           77.573638
# 2           77.573638
# 3           77.573638
# 4           77.575502

# %%
zomato['city'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1  775.0  Banashankari        Casual Dining
# 1          True       False   4.1  787.0  Banashankari        Casual Dining
# 2          True       False   3.8  918.0  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7   88.0  Banashankari          Quick Bites
# 4         False       False   3.8  166.0  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city                             liked_food_from_review  \
# 0  Banashankari  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  Banashankari  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  Banashankari  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  Banashankari  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  Banashankari  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined  location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...          12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...          12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...          12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...          12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...          12.941726
#
#    location_longitude
# 0           77.573638
# 1           77.573638
# 2           77.573638
# 3           77.573638
# 4           77.575502

# %%
## Checking Null values
zomato.isnull().sum()
# Out:
# address                   0
# name                      0
# online_order              0
# book_table                0
# rate                      0
# votes                     0
# location                  0
# rest_type                 0
# cuisines                  0
# cost                      0
# reviews_list              0
# menu_item                 0
# type                      0
# city                      0
# liked_food_from_review    0
# menus_combined            0
# location_latitude         0
# location_longitude        0
# dtype: int64

# %%
## Computing Mean Rating
restaurants = list(zomato['name'].unique())
zomato['Mean Rating'] = 0

for i in range(len(restaurants)):
    zomato['Mean Rating'][zomato['name'] == restaurants[i]] = zomato['rate'][zomato['name'] == restaurants[i]].mean()

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1  775.0  Banashankari        Casual Dining
# 1          True       False   4.1  787.0  Banashankari        Casual Dining
# 2          True       False   3.8  918.0  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7   88.0  Banashankari          Quick Bites
# 4         False       False   3.8  166.0  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city                             liked_food_from_review  \
# 0  Banashankari  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  Banashankari  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  Banashankari  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  Banashankari  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  Banashankari  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined  location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...          12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...          12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...          12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...          12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...          12.941726
#
#    location_longitude  Mean Rating
# 0           77.573638         4.15
# 1           77.573638         4.10
# 2           77.573638         3.80
# 3           77.573638         3.70
# 4           77.575502         3.80

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (1,5))

zomato[['Mean Rating']] = scaler.fit_transform(zomato[['Mean Rating']]).round(2)

zomato.sample(3)
# Out:
#                                                 address  \
# 428   21, 1st Floor, Next to Oracle, Kalyani Magnum ...
# 1575  Lemon Tree Hotel, 23, EPIP Zone, Near I Gate C...
# 2909  1702, 19th Main Road, Sector 2, HSR Layout, HS...
#
#                                 name  online_order  book_table  rate  votes  \
# 428                Tandoor And Spice          True       False   4.0  181.0
# 1575  Citrus Cafe - Lemon Tree Hotel         False       False   3.8  118.0
# 2909                         Feaster          True       False   3.8   88.0
#
#         location      rest_type  \
# 428     JP Nagar  Casual Dining
# 1575  Whitefield  Casual Dining
# 2909         HSR  Casual Dining
#
#                                                cuisines    cost  \
# 428          North Indian, Chinese, Biryani, Hyderabadi   550.0
# 1575     North Indian, Continental, South Indian, Asian  1900.0
# 2909  Continental, Asian, Chinese, Italian, North In...   600.0
#
#                                            reviews_list menu_item      type  \
# 428   [('Rated 5.0', 'RATED\n  A restaurant nearby t...        []  Delivery
# 1575  [('Rated 3.0', 'RATED\n  Went here on an eveni...        []    Buffet
# 2909  [('Rated 1.0', "RATED\n  I ordered beef fry an...        []  Delivery
#
#                    city                             liked_food_from_review  \
# 428   Bannerghatta Road  ['butter chicken', 'butter', 'chilly prawn', '...
# 1575        Brookefield  ['biscuits', 'biscuit', 'filter coffee', 'coff...
# 2909                HSR                                                 []
#
#                                          menus_combined  location_latitude  \
# 428   ['egg', 'biryani,', 'tandoori', 'chicken,', 'c...          12.907251
# 1575  ['breakfast', 'buffet', 'biscuits', 'biscuit',...          12.969637
# 2909             ['liver', 'fry,', 'burgers,', 'pizza']          12.914453
#
#       location_longitude  Mean Rating
# 428            77.578271         3.84
# 1575           77.749745         3.65
# 2909           77.642694         3.58

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1  775.0  Banashankari        Casual Dining
# 1          True       False   4.1  787.0  Banashankari        Casual Dining
# 2          True       False   3.8  918.0  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7   88.0  Banashankari          Quick Bites
# 4         False       False   3.8  166.0  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []  Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []  Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []  Buffet
#
#            city                             liked_food_from_review  \
# 0  Banashankari  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  Banashankari  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  Banashankari  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  Banashankari  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  Banashankari  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined  location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...          12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...          12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...          12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...          12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...          12.941726
#
#    location_longitude  Mean Rating
# 0           77.573638         4.03
# 1           77.573638         3.97
# 2           77.573638         3.58
# 3           77.573638         3.45
# 4           77.575502         3.58

# %% [markdown]
# ## Text Preprocessing
# Some of the common text preprocessing / cleaning steps are:
#
# Lower casing,
# Removal of Punctuations,
# Removal of Stopwords,
# Removal of URLs,
# Spelling correction,

# %%
# 5 examples of these columns before text processing:
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                            reviews_list  \
# 2097  [('Rated 4.0', "RATED\n  Beer Adda is a decent...
# 2500  [('Rated 4.0', "RATED\n  I visited this place ...
# 3212  [('Rated 4.0', 'RATED\n  Good food. The pepper...
# 2630  [('Rated 3.0', "RATED\n  It's a good restauran...
# 1731  [('Rated 4.0', 'RATED\n  Chai point is a great...
#
#                                                cuisines
# 2097                       North Indian, Chinese, Pizza
# 2500                                        Finger Food
# 3212                                             Kerala
# 2630  Arabian, Kerala, Biryani, South Indian, Chines...
# 1731                          Tea, Beverages, Fast Food

# %%
## Lower Casing
zomato["reviews_list"] = zomato["reviews_list"].str.lower()
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                            reviews_list  \
# 2199  [('rated 4.0', 'rated\n  a nice place to have ...
# 2114  [('rated 3.0', "rated\n  ordered garlic bread ...
# 839   [('rated 3.0', "rated\n  i've been here numero...
# 2229  [('rated 1.0', 'rated\n  i have been waiting f...
# 4513  [('rated 3.0', "rated\n  this place is known t...
#
#                                               cuisines
# 2199                             North Indian, Chinese
# 2114                        North Indian, Chinese, BBQ
# 839   South Indian, North Indian, Chinese, Street Food
# 2229                             North Indian, Chinese
# 4513                              North Indian, Kerala

# %%
## Removal of Puctuations
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_punctuation(text))
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                            reviews_list  \
# 2361  rated 40 ratedn  one of the favourite restaura...
# 2340  rated 50 ratedn  the food in the restaurant tr...
# 708   rated 50 ratedn  amazing snacks on the go a mu...
# 3919  rated 30 ratedn  located just opposite 1522it ...
# 2170  rated 40 ratedn  chicken lollipopnchicken loll...
#
#                                                cuisines
# 2361  Seafood, Biryani, South Indian, Chettinad, Chi...
# 2340                     North Indian, Chinese, Biryani
# 708                                 Beverages, Desserts
# 3919                  Finger Food, Continental, Chinese
# 2170             Biryani, Seafood, Andhra, North Indian

# %% [markdown]
# Removal of Stopwords
# from nltk.corpus import stopwords
# STOPWORDS = set(stopwords.words('english'))
# def remove_stopwords(text):
#     """custom function to remove the stopwords"""
#     return " ".join([word for word in str(text).split() if word not in STOPWORDS])
#
# zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_stopwords(text))

# %%
## Removal of URLS
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_urls(text))

# %%
zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                            reviews_list  \
# 2662  rated 40 ratedn  just tried theri bengali pula...
# 1943  rated 50 ratedn  have eaten here multiple time...
# 2588  rated 40 ratedn  my favourite go to place when...
# 256   rated 50 ratedn  if veg food tastes so good on...
# 337   rated 30 ratedn  food quality is okaynrui mach...
#
#                             cuisines
# 2662                         Bengali
# 1943                  Italian, Salad
# 2588  Beverages, Sandwich, Fast Food
# 256       North Indian, South Indian
# 337                          Bengali

# %%
# RESTAURANT NAMES:
restaurant_names = list(zomato['name'].unique())
restaurant_names
# Out:
# ['Jalsa',
#  'Spice Elephant',
#  'San Churro Cafe',
#  'Addhuri Udupi Bhojana',
#  'Grand Village',
#  'Timepass Dinner',
#  'Onesta',
#  'Penthouse Cafe',
#  'Smacznego',
#  'Cafe Down The Alley',
#  'Cafe Shuffle',
#  'The Coffee Shack',
#  'Caf-Eleven',
#  'Cafe Vivacity',
#  'Catch-Up-Ino',
#  "Kirthi'S Biryani",
#  'T3H Cafe',
#  'The Vintage Cafe',
#  'Woodee Pizza',
#  'My Tea House',
#  "Srinathji'S Cafe",
#  'Redberrys',
#  'Foodiction',
#  'Ovenstory Pizza',
#  'Faasos',
#  'Behrouz Biryani',
#  'Szechuan Dragon',
#  'Empire Restaurant',
#  'Chaatimes',
#  "Mcdonald'S",
#  "Domino'S Pizza",
#  'Hotboxit',
#  'Kitchen Garden',
#  'Recipe',
#  'Beijing Bites',
#  'Tasty Bytes',
#  'Corner House Ice Cream',
#  'Biryanis And More',
#  'Roving Feast',
#  'Freshmenu',
#  'Wamama',
#  'Peppy Peppers',
#  'Goa 0 Km',
#  '1947',
#  'Kabab Magic',
#  'Gustoes Beer House',
#  'The Biryani Cafe',
#  'Rolls On Wheels',
#  'Sri Guru Kottureshwara Davangere Benne Dosa',
#  'Upahar Sagar',
#  'Frozen Bottle',
#  'Meghana Foods',
#  'Nandhini Deluxe',
#  "Vi Ra'S Bar And Restaurant",
#  'Chatar Patar',
#  'Polar Bear',
#  "Kidambi'S Kitchen",
#  'Mane Thindi',
#  'Floured-Baked With Love',
#  'Bengaluru Coffee House',
#  'Anna Kuteera',
#  'Darbar',
#  'Sri Udupi Food Hub',
#  'House Of Kebabs',
#  'Roll N Rock',
#  'Box8- Desi Meals',
#  'Kfc',
#  'Roll Over',
#  'Imperial Restaurant',
#  'Wahab',
#  'Canton',
#  'The Blue Wagon - Kitchen',
#  'Patio 805',
#  'Lassi Corner',
#  'Sagar Deluxe',
#  'Energy Addaa',
#  'Tandoori Knight',
#  'Dev Sagar - Food Street',
#  'Mitraa Da Pizza',
#  'Grazers',
#  'Shakes Theory',
#  '@Italy',
#  'Old Mumbai Ice Cream',
#  'Donne Biriyani House',
#  "Kedia'S Fun Food",
#  'Just Shawarma',
#  'Mini Punjabi Dhaba',
#  'Gokul Veg',
#  'Olive - Era',
#  'Gama Gama',
#  'Pizza Hut',
#  'Mangalore Pearl',
#  'Twiststick House',
#  'Cool Corner',
#  'Pizza Mane',
#  'Dal Tadkaa',
#  'Chutney Chang',
#  'Mystique Palate',
#  'Thamboola',
#  'Castle Rock',
#  'Vietnamese Kitchen',
#  'Toscano',
#  'Stoned Monkey',
#  'Central Jail Restaurant',
#  'Bella',
#  'New Prashanth Hotel',
#  'Karma Kaapi',
#  "Tiwari'S",
#  'Pizza Stop',
#  "Biggies Burger 'N' More",
#  "Kollapuri'S",
#  'Rs Shiv Sagar',
#  'Harshi Super Sandwich',
#  'Ugadi',
#  'Subway',
#  'The Lassi Park',
#  'A2B - Adyar Ananda Bhavan',
#  'Srikrishna Bhavan',
#  'Green Gardenia',
#  'J Spice',
#  'Hatti Kaapi',
#  'Upahara Darshini',
#  'The Chaat Shop',
#  'Samskruti - Sanman Gardenia',
#  'Chumma Delicious',
#  'Dwaraka Grand',
#  'Gufha - The President Hotel',
#  'Mojo Pizza - 2X Toppings',
#  'South Kitchen',
#  'Chung Wah',
#  'Prems Graama Bhojanam',
#  'Java City',
#  'Kamat Bugle Rock',
#  'Puliyogare Point',
#  'Bangalore Agarwal Bhavan',
#  'Rustic Stove',
#  'De Thaali',
#  'Matru Sagar',
#  'Sea Spice By 7 Star',
#  'Desi Dawat',
#  'Cafe Aira',
#  'Mast Punjabi',
#  'South Grand',
#  'The Pizzeria',
#  'Ruchis Point',
#  'Firangi Bake',
#  'The Royal Corner - Pai Viceroy',
#  'Hara Fine Dine',
#  'Chocoberry',
#  'Waffle-A-Go Go',
#  'Cross Road Cafe',
#  'Bakers Town',
#  'Ivy',
#  'The Airos',
#  'Chai Kraft',
#  'The Trundle',
#  'The Krishna Grand Xpress',
#  'Udupi Grand',
#  'Little Cafe',
#  '1980S Games Cafe',
#  'Kadala Tarangaa',
#  'As On Fire',
#  'Curry Leaves',
#  'Magic Meals',
#  'Desi Cream Junction',
#  'Eat Repeat',
#  'Salut',
#  "Sandwich Mama'S And Frozen Monster",
#  'Food Springs',
#  "Chung'S Chinese Corner",
#  'Eurasia Pasta And Barbeque By Little Italy',
#  'Goli Vada Pav No. 1',
#  "Ragoo'S",
#  'Pure & Natural',
#  'Maiyas',
#  'Sip N Dine',
#  'Cafe Mondo',
#  'Jalpaan',
#  "Kataria'S Pakwan",
#  'Juicy Momos',
#  'Amande Patisserie',
#  'Anand Sweets And Savouries',
#  'Chicken Hunt',
#  'Swadesh Tadka',
#  'Cane-O-La',
#  'New Biryani Mane',
#  'Karnataka Bhel House',
#  'Sreeraj Lassi Bar',
#  "Bunt'S Biriyani Palace",
#  'Chai Point',
#  'Janahaar',
#  'Utsav',
#  'The Spice Saga',
#  'Subz',
#  'Mint And Mustard',
#  'Punjabi Raswada',
#  "Vinny'S",
#  "Kapoor'S Cafe",
#  'Sukh Sagar',
#  'Andhra Ruchulu',
#  'Steaming Mugs',
#  'Rajathadri Food Fort',
#  'Brew Meister',
#  'Rasoi',
#  'Mr. Singh Da Dhaba',
#  'Ayodhya Upachar',
#  'Biriyani Mane',
#  'Cafe Ajfan',
#  'Brundhavana Food Point',
#  'Slv Corner Restaurant',
#  'The Krishna Grand',
#  'Roti Ghar',
#  'Baisakhi',
#  'Poonam Sweets',
#  'Sri Venkateshwara Sweet Meat Stall',
#  'A2B Veg - Adyar Ananda Bhavan',
#  'Jcubez',
#  "Iyer'S Tiffin Centre",
#  'Taaza Thindi',
#  'Sri Laxmi Venkateshwara Coffee Bar',
#  'Messy Bowl',
#  'Hotel Mangala',
#  'Slv Swadishta',
#  'New Sagar Fast Food',
#  'Slv Refreshment',
#  'Kavali',
#  'Ranganna Military Hotel',
#  'Vidyarthi Bhavan',
#  'Bharjari Oota',
#  'Soho Bar & Grill',
#  'Bhavani Restaurant',
#  'Zephyr',
#  'Hotel Dwarka',
#  'Ma-Arya Family Restaurant',
#  'Udupi Sri Krishna Bhavan',
#  'Ice Thunder',
#  'Mahalaxmi Tiffin Room',
#  'Sandwichwallas',
#  'Basavanagudi Mylari',
#  'Pramukh Family Restaurant',
#  'Vybhava',
#  'Shree Venkateshwara North Karnataka Hotel',
#  'Belly Squad Food Truck',
#  'Deja Vu Resto Bar',
#  'Fattoush',
#  'Abhiruchi Hotel',
#  'Barbeque Nation',
#  'Sattvam',
#  '24Th Main',
#  'Zaitoon',
#  'Oye Amritsar',
#  'Melt - Eden Park',
#  'Spice Code',
#  'The Onyx - The Hhi Select Bengaluru',
#  'Sankranthi Veg Restaurant',
#  'Cafe Kabana',
#  'Butterly',
#  'Black Mug Cafe',
#  '#Refuel',
#  'Wafl',
#  'Vaho Kafe & Pressery',
#  'Dreamcatcher',
#  'Cafe Arabica',
#  'Kalmane Koffees',
#  'Brews N Bites',
#  'Slate Cafe',
#  'Dialogues',
#  'Mudpipe Cafe',
#  'Tab - Take A Break',
#  'Cafe Potpourri',
#  'Vinaya Coffee Moments',
#  'Cuppa',
#  'Skytouch Le Cafe',
#  'Eat.Fit',
#  'Sai Abhiruchi',
#  'Capsicum Family Restaurant',
#  'Easy Bites',
#  'Hiyar Majhe Kolkata',
#  'Sri Lakshmi Dhaba',
#  'Xo Belgian Waffle',
#  'Swadista Aahar',
#  'Al-Bek',
#  "Aniram'S",
#  'Punjabi Nawabi',
#  'Swad Punjab Da',
#  'Roti Wala',
#  'Midnight Mania',
#  'Kitchens@Jp Nagar',
#  'Krishna Kuteera',
#  'Apna Punjab',
#  'Paratha Junction',
#  'Nellore Bhojanam',
#  'Momoz',
#  'Kalingas',
#  'Kanteen The Eatery',
#  'Kullad Cafe',
#  'Litti Twist',
#  'Shanthi Sagar',
#  'Cakebuy',
#  'Five Star Chicken',
#  'Hind Ka Chulah',
#  'Bohra Bohra Cafe ',
#  'Biryani Durbar',
#  'Mahesh Friends Food Center',
#  'Burger King',
#  "Dadi'S Dum Biryani",
#  'Alankrutha',
#  'Paradise',
#  'Adithya',
#  'Cheesiano Pizza',
#  "Dande'S Hyderabad Biryani",
#  'Upahara Bhavan',
#  'Shuddh Desi Khana',
#  'Aramane Donne Biriyani',
#  "Mani'S Dum Biryani",
#  'Amontron',
#  'Birinz',
#  'Hyderabadi Bawarchi',
#  'Fish Chain',
#  'Prasiddhi Food Corner',
#  'Hyderabad Biryaani House',
#  "Galito'S",
#  'Rajdhani Thali Restaurant',
#  'Phew (Play Hard Eat Wild)',
#  'Chicken County Grand',
#  'Savoury - Sea Shell Restaurant',
#  'Kundana',
#  'The Shawarma Shop',
#  'Punjabi Food Corner',
#  'Mealer.In',
#  'Pathaan Sir',
#  'Cold Stone Creamery',
#  'Amritsari Kulcha Land',
#  'Chokha Chowka',
#  'Gorbandh',
#  'Grills & Rolls',
#  'Bathinda Junction',
#  'Stories',
#  'Kanti Sweets',
#  'Seasons',
#  'Marwa Restaurant',
#  'Shanghai Court',
#  'Bhojohori Manna',
#  'Hunger Bee',
#  'Yum In My Tum',
#  'Biryani Miya',
#  'Chulha Chauki Da Dhaba',
#  "Magix'S Parattha Roll",
#  'Elegant Dining',
#  'Waffle Head',
#  'Basmati Delights',
#  'Samosa Singh',
#  'Cravings',
#  'Matka',
#  'Punjabi Swag',
#  'Taco Bell',
#  "Mother'S Rasoi",
#  'Dosa Bazaar',
#  'The Bong Palate',
#  'Bikaner Jn',
#  'Crunch Pizzas',
#  'Kakal-Kai Ruchi',
#  'Calorie Express',
#  'Bangalore Box',
#  'Chavadi',
#  'Nanna Munna Paratha House',
#  'Cucumber Town',
#  'Brewsky',
#  'Chefeana',
#  'Bangaliana',
#  'Gud Dhani',
#  'Deejas Kitchen',
#  'Pancuzzi',
#  "Zhang'S - Chinese Restaurant",
#  'Shagun Sweets & Foods',
#  "Dev'S Gugababa",
#  'Oogway Express',
#  'The Egg Factory',
#  'Chow San',
#  'Momo Jojo',
#  'Simply Indian',
#  "Rithika'S Kitchen",
#  'Punjabi Times',
#  'Cravy Wings',
#  'Funky Punjab',
#  'Punjabi Corner',
#  'Zeeshan',
#  'Ambara Gardenia',
#  'More Pizza',
#  'Crafted Plate',
#  "Shetty'S Kitchen",
#  'Machali Port',
#  'Garma Garam',
#  'The Coastal Crew By Fujian On 24Th',
#  'Bib - Breakfast In The Box',
#  'Tandoor And Spice',
#  'Rock Stone Ice Cream Factory',
#  'Paratha Plaza',
#  'Namma Kudla',
#  'Wangs Kitchen',
#  'Spice Up',
#  'Tempteys',
#  'Crumb Together',
#  'The Foodyz',
#  'Meat And Eat',
#  'Nagarjuna',
#  'Laddoos',
#  'Waffle Stories',
#  'Late Night',
#  'Waffle Walle',
#  'Dakshin Cafe',
#  'Shake It Off',
#  'Two Friends Cauldron',
#  'Bun Town',
#  'Pot Biryani',
#  'Mango Tree- The Beer Garden',
#  'The Jade Kitchen',
#  'Drunken Monkey',
#  'Intalia',
#  'Hotel Aradhana',
#  'The Chervil',
#  'New Royal Treat',
#  'I Cool',
#  'Asha Sweets Centre',
#  'Vinaya Cafe',
#  'World Of Waffles',
#  'Oottupura Family Restaurant',
#  'Vyanjan',
#  "Watson'S",
#  'Chicken Man',
#  'Nandhana Palace',
#  'On The Nose',
#  'Udupi Thaja Thindi',
#  'Baba Ka Dhaba',
#  'Natural Ice Cream',
#  "Churchill'S",
#  'The Chocolate Room',
#  'Aramane Restaurant',
#  'Bawarchi Inn',
#  "Ruh'S Cafe",
#  'California Burrito',
#  'Tandoor Garden',
#  'Caffe Pascucci',
#  'Chaitanya Cafe',
#  'Berrylicious',
#  'Pappu Da Dhaba',
#  'Smoke - The Sizzler House',
#  'Chung Wah Opus',
#  'Dream A Dozen',
#  'Bread Crumbs Bakery',
#  'Nite Out',
#  'Willys Top Cafe',
#  "Woody'S",
#  'The Curry Hut Plus',
#  'Zhangs Classic',
#  'Guru Greens',
#  'D View Cafe',
#  'Flavour Of China',
#  'Kabab Treat',
#  'Casa Piccosa',
#  'Bake Addiction',
#  'Tongue Twisters',
#  'Vaathsalya Millet Cafe',
#  'Guru Garden',
#  'Brewz Coffee',
#  'Athithi',
#  'Sri Bhagya Grand',
#  'Flavorsome Bakes',
#  'Mast Kalandar',
#  'Shiv Sagar',
#  'Coastal Inn',
#  'Bangalir Rannaghar',
#  "Lalchee'S Rasoi",
#  'Kailash Parbat',
#  'Tandoor Hut',
#  'Zaika Take Away',
#  'Malhar Maharashtrian Cuisine',
#  'Mandi',
#  'Pallavi North Indian Veg Restaurant',
#  'Idly Pidly',
#  "Vasudev Adiga'S",
#  'Tgi Fridays',
#  'Apsara Ice Cream',
#  "Targaryen'S Kitchen",
#  'Desi Vibes',
#  'Kulfi & More',
#  'Dal Roti',
#  'Status',
#  'Bottle Breacher',
#  'Kesariya',
#  'Swad Restaurant',
#  'Checkpost',
#  'Nandhini Paradise',
#  'New Kabab Plaza',
#  'Coastal Mama',
#  'Waah Biryani',
#  'Rara Avis',
#  'Baskin Robbins',
#  'Royal Chef Naati Oota',
#  'Flow - Terrace Bar & Grill',
#  'Sree Krishna Kafe',
#  'Dilish Kitchens',
#  'Daily Bread',
#  "Owl'S Kitchen",
#  'Deccan Spice',
#  'Desi Wok',
#  'Namana Garden',
#  'Andhra Grills',
#  'Petoo',
#  'Night Panda',
#  'Kamat Swaad',
#  'Ishta Cafe',
#  'Cafe Mist',
#  'Fat Chef Biryani Wale',
#  "Amma'S Pastries",
#  'World On A Swirl',
#  'Sweet Truth',
#  'Cream Stone',
#  "Calvin'S",
#  'Veruthe Oru Thattukada',
#  'Guru Paradise',
#  'Purani Dilli By Anand Sweets',
#  'Ingu Tengu',
#  'Green Onion',
#  'Panchami Garden',
#  'Hakuna Matata',
#  'Three Dots & A Dash',
#  'Hunger Camp',
#  '55 Wall Street',
#  'Parkview',
#  'Danapani',
#  'Inchara',
#  'Kabab Mehal',
#  'Chatori Gali',
#  'White Horse',
#  'Coconut Grove',
#  'Tree Top',
#  'The Sofraah Kebabs & Kurries - Eden Park Restaurants',
#  'The Yellow Chilli',
#  'Tea Villa Cafe',
#  'Cafe Cosy',
#  'Go Native',
#  'Alchemy Coffee Roasters',
#  'Rooftop Cafe',
#  'Enerjuvate Studio & Cafe',
#  'The Caramelts Cafe',
#  'Slimsins Cafe',
#  'Krazzy Folds',
#  'Starbucks',
#  'La Grande Cafe',
#  '4Th Tea Block',
#  'People Tree Cafe',
#  'Leon Grill',
#  'Dr. Bubbles',
#  'Shanmukha',
#  'Bhukkhad Baba',
#  'Mysuru Coffee Thindi',
#  'Smoke-A-Pot',
#  'The Biriyani Pedia',
#  'Sl Vadapav',
#  "Wazir'S",
#  'Krispy Kreme',
#  'Keventers',
#  'Tummy Fuel',
#  'Pani Kum Chai',
#  'Rajanna Military Hotel',
#  'Protein Grillhouse',
#  'Punjabi By Nature 2.0',
#  'Peace Restaurant',
#  'Pin Me Down',
#  'Swathi Deluxe Restaurant',
#  'Cakewala',
#  'The Belgian Waffle Co.',
#  'Wat-A-Burger!',
#  'Vakulaa Veg Restaurant',
#  'Malabar Bay',
#  'Khan Saheb Grills And Rolls',
#  'Desi Vdesi',
#  'Bhavani Chats N Juice',
#  'Lit Gastro Pub',
#  'Ice Cream Works',
#  'Rahhams',
#  'Bubblewrap Waffle Co.',
#  'Grillopia',
#  'Navami',
#  'Ibaco',
#  'City Durbar',
#  'Indori Chatorey',
#  'Mockaholic Restro Beer Cafe',
#  '3 Spice',
#  'Mug N Bean',
#  'Pop Hop',
#  '1441 Pizzeria',
#  'Hari Super Sandwich',
#  'Shyvan Restaurant',
#  'Mecaf Family Restaurant',
#  'By 2 Coffee',
#  'Euki',
#  'Kalpavriksha Upahara',
#  'New Punjabi Hotel',
#  'Ice Land',
#  'Rajvardhan Foods',
#  'Desi Rasoi',
#  'Red Onion',
#  'Baba Chatkora',
#  'Mainland China',
#  'Kamat Minerva',
#  'Davangere Benna Dose Hotel',
#  'Kudla - Hotel Ramanashree',
#  "Anupam'S Coastal Express",
#  "Polamma'S Mess",
#  'Cable Car',
#  'Vindu Andhra Ruchulu',
#  'Tawa Sagara',
#  'The Lounge - Eden Park Restaurants',
#  'Mayuri',
#  'Parika Multicuisine Restaurant',
#  'Eshanya',
#  'Siddique Kabab Centre',
#  'Clove Rooftop',
#  'Chef Master',
#  'Mane Holige',
#  'Nagarjuna Chimney',
#  "Mishra'S Pedha Big Foods",
#  'La Casa',
#  'Divina - Eden Park Restaurants',
#  'Parivar',
#  'V B Bakery',
#  'Milano Ice Cream',
#  'Cool Joint',
#  'The Rogue Elephant',
#  'Beetle Juice Bar - Springs Hotel & Spa',
#  'Mavalli Tiffin Room (Mtr)',
#  "Brahmin'S Coffee Bar",
#  'New Modern Hotel',
#  'Hotel Janatha',
#  'New Shanthi Sagar',
#  'Once Upon A Rooftop',
#  'Saarangi Fine Dining',
#  'Golden Oak - La Marvella Sarovar Premiere Hotel',
#  'Halli Jonne Biriyani',
#  'Bengaluru Cafe',
#  'Taj Restaurant',
#  'Brahmin Tiffins & Coffee',
#  "Sarvam'S",
#  "Iyengar'S Inn",
#  "Adiga'S",
#  'Pavithra Restaurant',
#  'Kava - Fairfield By Marriott',
#  "The Fisherman'S Wharf",
#  'Momo Cafe - Courtyard By Marriott',
#  'Ruh',
#  'Tipsy Bull - The Bar Exchange',
#  'Nook - Aloft Bengaluru Cessna Business Park',
#  'Chaarcoal',
#  'Sharaab Factory',
#  'Skylit - Citrus Hotels',
#  'Flavors Of India',
#  'Biso - Citrus Hotels',
#  "Chef'S Gallery",
#  "Palki'S",
#  'W Xyz Bar - Aloft Bengaluru Cessna Business Park',
#  'The Black Pearl',
#  'Jalsa Gold',
#  "Ab'S - Absolute Barbecues",
#  'The Hidden Home',
#  'Barbecoa',
#  'Opus Food Stories',
#  'Village - The Soul Of India',
#  'Little Italy',
#  'Xtreme Sports Bar',
#  'Rroyal Rajasthan',
#  'Flavours - Octave Hotel & Spa',
#  'Equinox Bar - Doubletree Suites By Hilton',
#  'The Salad Studio',
#  "Chef Baker'S",
#  'Cafe Coffee Day',
#  'Delitz Creamvilla Cafe',
#  'The Brewing Bean',
#  'Cafe Olive',
#  'Cafe Thulp',
#  'Stoner',
#  "Zoey'S",
#  'Eating Love',
#  'Light House Cafe',
#  'Sher-E-Punjab',
#  'Blue Berry Restaurant',
#  'Udupi Ruchi',
#  'Rangla Punjab',
#  'Thiruvithamkoor Restaurant',
#  'The Paratha Company',
#  'Nu.Tree',
#  'Best Of Bengal',
#  'New Punjabi Dhaba',
#  'Punjabi Dawat',
#  'Phulke Ghar Ke',
#  'The Meal Story',
#  'Meghana Foods Grand',
#  'Murli',
#  'Barbeque Delight',
#  'Basmati Restaurant',
#  'Fun Kitchen',
#  'Moriz Restaurant',
#  'Biryani Kitchen',
#  'Udupi Aatithya',
#  'Pepperwood',
#  'Al Daaz',
#  'Bihar Ki Shan',
#  'Sai Santhi Cafe',
#  'Shudh',
#  'Potful',
#  'Bahar Cafe',
#  'Dinepost9',
#  'Thalassery Restaurant',
#  'Sri Vishnu Grand',
#  'Bathinda Dine',
#  'Wow! Momo',
#  'Maa Bhook Lagi',
#  'Cake Town Cafe',
#  'Kairali Restaurant',
#  'Punjabi Food Point',
#  'Punjabi Tadka',
#  'Sri Udupi Park',
#  'The Punjabi Rasoi',
#  'Punjabi Nukkad Pure Veg',
#  'Kya Khaoge',
#  'Rayalaseema Chefs',
#  'The Nosh House',
#  'Savoury Restaurant',
#  'The Flying Cup',
#  'The Rasaganga',
#  'Sarjapur Social',
#  'Konaseema Kitchen',
#  "Psv'S Andhra Paradise",
#  'Maia - Eat | Bake | Mom',
#  'Happy Endings',
#  'Meghana Biryani',
#  'Andhra Bhojanam',
#  'Hyderabad Chefs',
#  'Byg Brewski Brewing Company',
#  'Suryawanshi',
#  "Chili'S American Grill & Bar",
#  'Delite Chaat House',
#  'Sri Krishna Sagar',
#  'Dhaba Estd 1986 Delhi',
#  'Inhouse Burger',
#  'Manchow',
#  'La Casa Brewery And Kitchen',
#  'Biriyani Zone',
#  "Soup'Ermanz Kitchen",
#  'Healthie',
#  'Sri Dalma',
#  "Baker'S Home",
#  'Al Khansah',
#  'Chullah Bhatti',
#  'Feel@Home',
#  'The Kebab House',
#  'Poha On Wheels',
#  'Float',
#  'Innerchef',
#  'Broadway - The Gourmet Theatre',
#  'Grigliato',
#  'Crunch Pizzas - Express Delivery',
#  'Parrattha Ssinghh',
#  'Yummy Tummy',
#  'Lungees Foods',
#  'Bombay Brasserie',
#  'Ajwa Thalassery Biryani',
#  'Folklore Restaurant',
#  'Napoli Italian Bistro',
#  'Uptown Sliders & Shakes',
#  'The Grub Central',
#  'Juice Junction Food Court',
#  'Sintales',
#  'The Litti Company',
#  'Vandana Andhra And Multi Cuisine',
#  'Aashish Foods',
#  'Rusbury Fresh Sweets And Savouries',
#  'Shree Khana Khazana',
#  'Moti Mahal Delux',
#  'Shri Vishnu Grand',
#  'Kitchen On Table',
#  'Charcoal Eats',
#  'Zayakedar',
#  'Amrutha Grand Restaurant',
#  "Nanda'S",
#  "Srinathji'S",
#  'Sichuan',
#  'Kanua',
#  "Dad'S Cookhouse",
#  'Abbabi Chicken',
#  'Azura Restaurant',
#  "Ritomi'S Lov",
#  'Southinn',
#  'Smoor',
#  'Mughal Treat',
#  'Le Charcoal Xpress',
#  'Foxtrot',
#  'Le Gateau - The Cake Shop',
#  'Deli Chats And Sweets',
#  'Eden Huts Restaurant',
#  'Baithak',
#  'Mumbai Xpress',
#  'Filmy Kitchen',
#  'Samaroh',
#  'Fusion Tadka',
#  'Nh-1',
#  'Matinee Bar & Kitchen',
#  'Delhi Restaurant',
#  'Chatorezz',
#  'Aapni Rasoi',
#  'Tapout Tavern',
#  'Shanghai Bistro',
#  'Hyderabad Biryaani Home',
#  "Pabrai'S Fresh & Naturelle Icecreams",
#  'Kritunga Restaurant',
#  'Kabab Mandra',
#  'Hoot',
#  'Ice N Fries Cafe',
#  'Nutty Squirrel',
#  'Cooking Mom',
#  'Biriyani Bungalow',
#  'Absolute Shawarma',
#  'The Irish House',
#  "Gusto'S Pizza",
#  'Mak N Vak - Fyn',
#  'Carlos Cake Cafe',
#  'Mighty Paws',
#  'Brimstone Cafe',
#  'Jashn',
#  'Health Zingo',
#  'Soul Treat',
#  'Kadala Teera',
#  'Red Stone Kitchen',
#  'Second Wife Cafe',
#  'The Vape',
#  'Nukkad',
#  'Burrito Boys',
#  'Dhaba Shaba',
#  'Ghar Ka Chulha',
#  'Cafe Daily Bread',
#  'Mishmash',
#  'Sri Sai Mango Tree Restaurant',
#  'Bhagini',
#  'Unico',
#  'Dosa Time',
#  "Ammi'S Biryani",
#  'Readybowl',
#  'Kawaii',
#  'B.M.W - Bhookh Mitaane Wala',
#  'Lovely Knights',
#  'Bonfooder',
#  'Cafe At The Atelier',
#  'Eatsomnia',
#  'Spice Of Kolkata',
#  'Spice Garden By Dum Mast Biryani',
#  'Parathabox',
#  'La-Pizza',
#  'That Garage Cafe',
#  'Cupcake Noggins',
#  'Swathi Deluxe',
#  'The Rig',
#  'Butter Side Up',
#  'Just Delhiwala',
#  'Foodzoo',
#  'Mumbai Kulfi',
#  'Wow Vada Pav',
#  'Nayi Dilli By Anand Sweets',
#  'Cauvery Hyderabadi Biriyani',
#  'Health Gourmet',
#  'Hokey Pokey Ice Creams',
#  'Warm Oven',
#  'Chullah Chandigarh',
#  'Dalchini',
#  "Bg'S Poolside Bar & Grill",
#  'Glassy',
#  'Opus Club',
#  'Vapour Brewpub And Diner',
#  'Blue Terrain - Novotel',
#  'Asia Alive - Doubletree Suites By Hilton',
#  'The Square - Novotel',
#  'Chez Nous - Novotel',
#  'Madurai Idly Shop',
#  'Ebony',
#  'Panchavati Gaurav Thali',
#  'Saatvikk',
#  '70 Brigade - Iris Hotel',
#  'Olive Bar And Kitchen',
#  'Jw Kitchen - Jw Marriott Bengaluru',
#  'The Tao Terraces',
#  'Rim Naam - The Oberoi',
#  'Oh! Calcutta',
#  'Caraway Kitchen - Conrad Bengaluru',
#  'Rasovara',
#  'Cubbon Pavilion - Itc Gardenia',
#  'Le Jardin - The Oberoi',
#  'Bbq@52',
#  'Konark Vegetarian Restaurant',
#  'The Spice Bazaar',
#  "Bbq'D - Global Grill & Brewery",
#  'The Market - The Ritz-Carlton',
#  'Welcomcafe Jacaranda - Welcomhotel Bengaluru',
#  'Season - Adarsh Hamilton',
#  'Puran Da Dhaba - The Pride Hotel',
#  'Cafe Mangii',
#  'Ithaca - The Chancery Pavilion',
#  'Tiger Trail - Ramada Hotel',
#  'Citrus Cafe - Lemon Tree Premier',
#  'The Oriental Spice - Ashraya Hotel',
#  'Pinxx - Royal Orchid Central',
#  'Monsoon - The Park Bangalore',
#  'Cafe Treat - The Pride Hotel',
#  'South Parade - The Chancery Hotel',
#  'Mint Masala',
#  "Curry With A 'K' - St. Mark'S Hotel",
#  'Northern Gate- Gateway Hotel',
#  'Canopy',
#  'Cafe @ Elanza',
#  'Sunehri',
#  'Spice It',
#  'Banjara Melting Pot',
#  'Zodiac - Fortune Select Jp Cosmos Hotel',
#  'One Atria Cafe',
#  'Blow',
#  'Cafe Azzure',
#  'Trick Or Treat',
#  "Fatso'S",
#  'Bon Sante',
#  'Brik Oven',
#  'Green Theory',
#  'Truffles',
#  'Cafe Felix',
#  'The White Room - Coffee & Kitchen',
#  'Matteo Coffea',
#  "Glen'S Bakehouse",
#  'Cafe Mozaic - Taj Mg Road Bengaluru',
#  "Smally'S Resto Cafe",
#  'Bengaluru Baking Company - Jw Marriott Bengaluru',
#  'Cafe Kaara',
#  'Japan Travel Cafe Azuki',
#  'Little Green Cafe',
#  "Cafe Mor'Ish",
#  'Skoolroom',
#  'Lakeview Milkbar',
#  "Wolf'Ish",
#  'Urban Solace - Cafe For The Soul',
#  'Peppa Zzing',
#  'The Courtyard',
#  'Cafe Imroze',
#  'Kaara By The Lake',
#  'Happy Belly Bakes',
#  'Cafe Cassia& Deli',
#  'The Blackboard Bakery',
#  'Wafl Cafe ',
#  'Fresh Pressery Cafe',
#  'Tata Cha',
#  'Moto Store & Cafe ',
#  'Driven Cafe',
#  'Soul Cafe',
#  'Cafe Aladdin',
#  'Cafe Cerrise',
#  'The Coffee Bean & Tea Leaf',
#  'Berrylicious Cafe',
#  'Hammered',
#  'Dolci Desserts',
#  'Infinitea Tea Room & Tea Store',
#  'Kerala Pavilion',
#  'Sri Ganesh Juice Junction',
#  "Dunkin' Donuts",
#  'Punjabi Dhaba',
#  'Tadkawala',
#  'Roti Shotti',
#  "Nando'S",
#  'Kc Das',
#  'M.M.A Kababs Rolls & Biryani Center',
#  'Richie Rich',
#  'Belgian Waffle Factory',
#  'No 10 Fort Cochin',
#  'Karama Restaurant',
#  "The Mughal'S",
#  'Kkr Foodies',
#  'Xpress Biryani',
#  'Soda Bottle Opener Wala',
#  'Smoke House Deli',
#  'Thai Chy',
#  'Kaati Zone',
#  'Portland Steakhouse & Cafe',
#  'Utse Kitchen',
#  'Alampur Bar And Restaurant',
#  'Sgs Non Veg - Gundu Pulav',
#  'Hotel Fanoos',
#  'Laughing Llama Gastropub',
#  'Oregano Pizzeria',
#  'The Good Grain',
#  'Pasta Street',
#  'Cita Pani',
#  'The Waffle Press',
#  'Delicacy',
#  'Mamagoto',
#  "Atty'S Bakery",
#  ...]

# %%
def get_top_words(column, top_nu_of_words, nu_of_word):
    
    vec = CountVectorizer(ngram_range= nu_of_word, stop_words='english')
    
    bag_of_words = vec.fit_transform(column)
    
    sum_words = bag_of_words.sum(axis=0)
    
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    
    return words_freq[:top_nu_of_words]

# %%
zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1  775.0  Banashankari        Casual Dining
# 1          True       False   4.1  787.0  Banashankari        Casual Dining
# 2          True       False   3.8  918.0  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7   88.0  Banashankari          Quick Bites
# 4         False       False   3.8  166.0  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list menu_item    type  \
# 0  rated 40 ratedn  a beautiful place to dine int...        []  Buffet
# 1  rated 40 ratedn  had been here for dinner with...        []  Buffet
# 2  rated 30 ratedn  ambience is not that good eno...        []  Buffet
# 3  rated 40 ratedn  great food and proper karnata...        []  Buffet
# 4  rated 40 ratedn  very good restaurant in neigh...        []  Buffet
#
#            city                             liked_food_from_review  \
# 0  Banashankari  ['fried rice', 'soya chaap', 'kulcha', 'rice',...
# 1  Banashankari  ['chicken', 'fried rice', 'chicken biryan', 'c...
# 2  Banashankari  ['veggies', 'egg', 'pasta', 'cake', 'chocolate...
# 3  Banashankari  ['pulka', 'apple', 'rice with sambar', 'dosa',...
# 4  Banashankari  ['roti', 'noodles', 'kulcha', 'pav bhaji', 'pa...
#
#                                       menus_combined  location_latitude  \
# 0  ['pasta,', 'lunch', 'buffet,', 'masala', 'papa...          12.915382
# 1  ['momos,', 'lunch', 'buffet,', 'chocolate', 'n...          12.915382
# 2  ['churros,', 'cannelloni,', 'minestrone', 'sou...          12.915382
# 3  ['masala', 'dosa', 'pulka', 'apple', 'rice wit...          12.915382
# 4  ['panipuri,', 'gol', 'gappe', 'roti', 'noodles...          12.941726
#
#    location_longitude  Mean Rating
# 0           77.573638         4.03
# 1           77.573638         3.97
# 2           77.573638         3.58
# 3           77.573638         3.45
# 4           77.575502         3.58

# %%
zomato.sample(5)
# Out:
#                                                 address  \
# 2286  124, Near Jyothi Nivas College, Koramangala 5t...
# 3573  80 Feet Road, 1st Stage, Opposite BDA Complex,...
# 799         89/1, Service Road, Marathahalli, Bangalore
# 662   68, 10th Main Road, 36th Cross, 5th Block, Jay...
# 3932  2/10, 80 Feet Road, RMV 2nd Stage, Poojary Lay...
#
#                                   name  online_order  book_table  rate  votes  \
# 2286                  Peace Restaurant          True       False   3.8  658.0
# 3573  Angaar Indian Grill & Restaurant         False       False   3.9  121.0
# 799                   Moriz Restaurant          True       False   2.9  666.0
# 662                            Pop Hop          True       False   4.1  204.0
# 3932                      Cafe Rossini          True       False   3.9  431.0
#
#                    location       rest_type  \
# 2286  Koramangala 5th Block   Casual Dining
# 3573             HBR Layout   Casual Dining
# 799            Marathahalli   Casual Dining
# 662               Jayanagar  Dessert Parlor
# 3932           New BEL Road   Casual Dining
#
#                                               cuisines   cost  \
# 2286                                  Chinese, Tibetan  500.0
# 3573    Arabian, Mughlai, North Indian, Chinese, Rolls  600.0
# 799   Arabian, North Indian, Seafood, Chinese, Biryani  800.0
# 662                                Ice Cream, Desserts  300.0
# 3932                     Continental, Italian, Chinese  700.0
#
#                                            reviews_list  \
# 2286  rated 30 ratedn  went here after a long day of...
# 3573  rated 40 ratedn  when mutton is served in the ...
# 799   rated 30 ratedn  i am a fan of this joint they...
# 662   rated 50 ratedn  great place for some yummy ic...
# 3932  rated 50 ratedn  i ordered the chinese chop su...
#
#                                               menu_item      type  \
# 2286                                                 []  Delivery
# 3573                                                 []  Delivery
# 799                                                  []  Delivery
# 662                                                  []  Delivery
# 3932  ['Cream of Chicken Soup', 'Veg Italiano Pasta'...  Delivery
#
#               city                             liked_food_from_review  \
# 2286           BTM  ['chicken', 'noodles', 'schezwan noodles', 'ri...
# 3573  Kalyan Nagar                                           ['rice']
# 799      Bellandur  ['mushroom', 'gobi manchurian', 'grape', 'veg ...
# 662   Basavanagudi  ['hazelnut', 'mocha ice cream', 'badam', 'moji...
# 3932  Malleshwaram  ['latte', 'rice', 'dates', 'pasta', 'veg start...
#
#                                          menus_combined  location_latitude  \
# 2286  ['momos,', 'thukpa,', 'dumplings,', 'crispy', ...          12.934011
# 3573  ['shawarma,', 'mutton', 'biryani,', 'angara', ...          13.035870
# 799   ['shawarma,', 'chicken', 'masala,', 'chicken',...          12.955257
# 662   ['choco', 'hazelnut,', 'belgian', 'chocolate,'...          12.929273
# 3932  ['pasta,', 'sandwiches,', 'chilli', 'paneer,',...          13.028825
#
#       location_longitude  Mean Rating
# 2286           77.622230         2.63
# 3573           77.632360         3.71
# 799            77.698416         2.37
# 662            77.582423         3.90
# 3932           77.571148         3.71

# %%
zomato.shape
# Out:
# (4529, 19)

# %%
zomato.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city', 'liked_food_from_review', 'menus_combined',
#        'location_latitude', 'location_longitude', 'Mean Rating'],
#       dtype='object')

# %%
zomato=zomato.drop(['address','rest_type', 'type', 'menu_item', 'votes'],axis=1)

# %%
import pandas

# Randomly sample 60% of your dataframe
df_percent = zomato.sample(frac=0.5)

# %%
df_percent.shape
# Out:
# (2264, 14)

# %% [markdown]
# ## Term Frequency-Inverse Document Frequency
# Term Frequency-Inverse Document Frequency (TF-IDF) vectors for each document. This will give you a matrix where each column represents a word in the overview vocabulary (all the words that appear in at least one document) and each column represents a restaurant, as before.
#
# TF-IDF is the statistical method of evaluating the significance of a word in a given document.
#
# TF — Term frequency(tf) refers to how many times a given term appears in a document.
#
# IDF — Inverse document frequency(idf) measures the weight of the word in the document, i.e if the word is common or rare in the entire document. The TF-IDF intuition follows that the terms that appear frequently in a document are less important than terms that rarely appear. Fortunately, scikit-learn gives you a built-in TfIdfVectorizer class that produces the TF-IDF matrix quite easily.

# %%
df_percent.set_index('name', inplace=True)

# %%
indices = pd.Series(df_percent.index)

# %%
# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend(name, cosine_similarities = cosine_similarities):
    
    # Create a list to put top 10 restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['cuisines', 'Mean Rating', 'cost'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_percent[['cuisines','Mean Rating', 'cost']][df_percent.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines','Mean Rating', 'cost'], keep=False)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)
    
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new

# %%
# HERE IS A RANDOM RESTAURANT. LET'S SEE THE DETAILS ABOUT THIS RESTAURANT:
df_percent[df_percent.index == 'Pai Vihar'].head()
# Out:
#            online_order  book_table  rate       location  \
# name
# Pai Vihar          True       False   2.8  Vasanth Nagar
# Pai Vihar         False       False   3.2    City Market
#
#                                                 cuisines   cost  \
# name
# Pai Vihar  South Indian, Street Food, Chinese, Fast Food  400.0
# Pai Vihar  South Indian, Street Food, Chinese, Fast Food  400.0
#
#                                                 reviews_list          city  \
# name
# Pai Vihar  rated 20 ratedn  a nice place in vasanthnagar ...  Brigade Road
# Pai Vihar  rated 20 ratedn  food was dry and bland i dont...  Brigade Road
#
#           liked_food_from_review                 menus_combined  \
# name
# Pai Vihar                     []  ['masala', 'dosa,', 'coffee']
# Pai Vihar                     []                       ['vada']
#
#            location_latitude  location_longitude  Mean Rating
# name
# Pai Vihar          12.988721           77.585169         2.55
# Pai Vihar          12.965718           77.576271         2.55

# %%
recommend('Pai Vihar')
# Out:
# TOP 10 RESTAURANTS LIKE Pai Vihar WITH SIMILAR REVIEWS:
#                                                                                  cuisines  \
# Brew And Barbeque - A Microbrewery Pub              Continental, North Indian, BBQ, Steak
# Dyu Art Cafe                                                     Cafe, Italian, Fast Food
# The Reservoire                          Continental, North Indian, Chinese, American, ...
# Foxtrot                                         North Indian, Chinese, Continental, Momos
# Hoot                                                   Continental, Italian, North Indian
# Bonsouth                                                        Chettinad, Andhra, Kerala
# Mavalli Tiffin Room (Mtr)                                         South Indian, Beverages
# Samosa Party                                                       Street Food, Fast Food
# Krishna Kuteera                                       South Indian, North Indian, Chinese
# Udupi Aatithya                                        South Indian, North Indian, Chinese
#
#                                         Mean Rating    cost
# Brew And Barbeque - A Microbrewery Pub         4.74  1400.0
# Dyu Art Cafe                                   4.48   800.0
# The Reservoire                                 4.48  1300.0
# Foxtrot                                        4.35  1200.0
# Hoot                                           4.10  1400.0
# Bonsouth                                       4.10  1300.0
# Mavalli Tiffin Room (Mtr)                      4.05   300.0
# Samosa Party                                   3.97   150.0
# Krishna Kuteera                                3.84   400.0
# Udupi Aatithya                                 3.84   300.0

# %% [markdown]
# References
#
# Recommender Systems in Python 101
# How to build a Restaurant Recommendation Engine
# Getting started with Text Preprocessing

# %% [markdown]
# End of the Notebook
